# %%
# !pip install openai langchain faiss-cpu unstructured pdfplumber tiktoken
# !pip install ragas datasets evaluate
# !pip install sentence-transformers
# Out:
# Collecting openai
#   Using cached openai-1.93.1-py3-none-any.whl.metadata (29 kB)
# Collecting langchain
#   Using cached langchain-0.3.26-py3-none-any.whl.metadata (7.8 kB)
# Collecting faiss-cpu
#   Using cached faiss_cpu-1.11.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting unstructured
#   Using cached unstructured-0.18.3-py3-none-any.whl.metadata (24 kB)
# Collecting pdfplumber
#   Using cached pdfplumber-0.11.7-py3-none-any.whl.metadata (42 kB)
# Collecting tiktoken
#   Using cached tiktoken-0.9.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from openai) (4.9.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Using cached jiter-0.10.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: sniffio in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from openai) (1.3.1)
# Collecting tqdm>4 (from openai)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from openai) (4.14.1)
# Collecting langchain-core<1.0.0,>=0.3.66 (from langchain)
#   Using cached langchain_core-0.3.68-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8 (from langchain)
#   Using cached langchain_text_splitters-0.3.8-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith>=0.1.17 (from langchain)
#   Using cached langsmith-0.4.4-py3-none-any.whl.metadata (15 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Using cached sqlalchemy-2.0.41-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3,>=2 in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from langchain) (6.0.2)
# Collecting numpy<3.0,>=1.25.0 (from faiss-cpu)
#   Using cached numpy-2.3.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: packaging in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from faiss-cpu) (25.0)
# Collecting chardet (from unstructured)
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting filetype (from unstructured)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured)
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting lxml (from unstructured)
#   Using cached lxml-6.0.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting nltk (from unstructured)
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: beautifulsoup4 in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from unstructured) (4.13.4)
# Collecting emoji (from unstructured)
#   Using cached emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting dataclasses-json (from unstructured)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting python-iso639 (from unstructured)
#   Using cached python_iso639-2025.2.18-py3-none-any.whl.metadata (14 kB)
# Collecting langdetect (from unstructured)
#   Using cached langdetect-1.0.9-py3-none-any.whl
# Collecting rapidfuzz (from unstructured)
#   Using cached rapidfuzz-3.13.0-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting backoff (from unstructured)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting unstructured-client (from unstructured)
#   Using cached unstructured_client-0.38.1-py3-none-any.whl.metadata (21 kB)
# Collecting wrapt (from unstructured)
#   Using cached wrapt-1.17.2-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: psutil in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from unstructured) (7.0.0)
# Collecting python-oxmsg (from unstructured)
#   Using cached python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting html5lib (from unstructured)
#   Using cached html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting pdfminer.six==20250506 (from pdfplumber)
#   Using cached pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Collecting Pillow>=9.1 (from pdfplumber)
#   Using cached pillow-11.3.0-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Using cached pypdfium2-4.30.1-py3-none-win_amd64.whl.metadata (48 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from pdfminer.six==20250506->pdfplumber) (3.4.2)
# Collecting cryptography>=36.0.0 (from pdfminer.six==20250506->pdfplumber)
#   Using cached cryptography-45.0.5-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting regex>=2022.1.18 (from tiktoken)
#   Using cached regex-2024.11.6-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: idna>=2.8 in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.66->langchain)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.66->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting packaging (from faiss-cpu)
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith>=0.1.17->langchain)
#   Using cached orjson-3.10.18-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith>=0.1.17->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard<0.24.0,>=0.23.0 (from langsmith>=0.1.17->langchain)
#   Using cached zstandard-0.23.0-cp312-cp312-win_amd64.whl.metadata (3.0 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=1.9.0->openai)
#   Using cached pydantic_core-2.33.2-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=1.9.0->openai)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Collecting greenlet>=1 (from SQLAlchemy<3,>=1.4->langchain)
#   Using cached greenlet-3.2.3-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: colorama in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from beautifulsoup4->unstructured) (2.7)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->unstructured)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->unstructured)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.9 in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Collecting click (from nltk->unstructured)
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting joblib (from nltk->unstructured)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting olefile (from python-oxmsg->unstructured)
#   Using cached olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured)
#   Using cached aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from unstructured-client->unstructured) (1.6.0)
# Collecting pypdf>=4.0 (from unstructured-client->unstructured)
#   Using cached pypdf-5.7.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: cffi>=1.14 in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (1.17.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: pycparser in c:\misogi\week5\day1\rag_evaluation\medical_ragas\myenv\lib\site-packages (from cffi>=1.14->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (2.22)
# Using cached openai-1.93.1-py3-none-any.whl (755 kB)
# Using cached langchain-0.3.26-py3-none-any.whl (1.0 MB)
# Using cached faiss_cpu-1.11.0-cp312-cp312-win_amd64.whl (15.0 MB)
# Using cached unstructured-0.18.3-py3-none-any.whl (1.8 MB)
# Using cached pdfplumber-0.11.7-py3-none-any.whl (60 kB)
# Using cached pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
# Using cached tiktoken-0.9.0-cp312-cp312-win_amd64.whl (894 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.10.0-cp312-cp312-win_amd64.whl (206 kB)
# Using cached langchain_core-0.3.68-py3-none-any.whl (441 kB)
# Using cached langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)
# Using cached langsmith-0.4.4-py3-none-any.whl (367 kB)
# Using cached numpy-2.3.1-cp312-cp312-win_amd64.whl (12.7 MB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Using cached pillow-11.3.0-cp312-cp312-win_amd64.whl (7.0 MB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp312-cp312-win_amd64.whl (2.0 MB)
# Using cached pypdfium2-4.30.1-py3-none-win_amd64.whl (3.0 MB)
# Using cached regex-2024.11.6-cp312-cp312-win_amd64.whl (273 kB)
# Using cached sqlalchemy-2.0.41-cp312-cp312-win_amd64.whl (2.1 MB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached emoji-2.14.1-py3-none-any.whl (590 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Using cached lxml-6.0.0-cp312-cp312-win_amd64.whl (4.0 MB)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Using cached python_iso639-2025.2.18-py3-none-any.whl (167 kB)
# Using cached python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Using cached python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Using cached rapidfuzz-3.13.0-cp312-cp312-win_amd64.whl (1.6 MB)
# Using cached unstructured_client-0.38.1-py3-none-any.whl (212 kB)
# Using cached wrapt-1.17.2-cp312-cp312-win_amd64.whl (38 kB)
# Using cached aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached cryptography-45.0.5-cp311-abi3-win_amd64.whl (3.4 MB)
# Using cached greenlet-3.2.3-cp312-cp312-win_amd64.whl (297 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached orjson-3.10.18-cp312-cp312-win_amd64.whl (134 kB)
# Using cached pypdf-5.7.0-py3-none-any.whl (305 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached zstandard-0.23.0-cp312-cp312-win_amd64.whl (495 kB)
# Using cached click-8.2.1-py3-none-any.whl (102 kB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached olefile-0.47-py2.py3-none-any.whl (114 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: filetype, zstandard, wrapt, typing-inspection, tqdm, tenacity, regex, rapidfuzz, python-magic, python-iso639, pypdfium2, pypdf, pydantic-core, Pillow, packaging, orjson, olefile, numpy, mypy-extensions, lxml, langdetect, jsonpatch, joblib, jiter, html5lib, greenlet, emoji, distro, click, chardet, backoff, annotated-types, aiofiles, typing-inspect, tiktoken, SQLAlchemy, requests-toolbelt, python-oxmsg, pydantic, nltk, marshmallow, faiss-cpu, cryptography, unstructured-client, pdfminer.six, openai, langsmith, dataclasses-json, unstructured, pdfplumber, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
# Successfully installed Pillow-11.3.0 SQLAlchemy-2.0.41 aiofiles-24.1.0 annotated-types-0.7.0 backoff-2.2.1 chardet-5.2.0 click-8.2.1 cryptography-45.0.5 dataclasses-json-0.6.7 distro-1.9.0 emoji-2.14.1 faiss-cpu-1.11.0 filetype-1.2.0 greenlet-3.2.3 html5lib-1.1 jiter-0.10.0 joblib-1.5.1 jsonpatch-1.33 langchain-0.3.26 langchain-core-0.3.68 langchain-text-splitters-0.3.8 langdetect-1.0.9 langsmith-0.4.4 lxml-6.0.0 marshmallow-3.26.1 mypy-extensions-1.1.0 nltk-3.9.1 numpy-2.3.1 olefile-0.47 openai-1.93.1 orjson-3.10.18 packaging-24.2 pdfminer.six-20250506 pdfplumber-0.11.7 pydantic-2.11.7 pydantic-core-2.33.2 pypdf-5.7.0 pypdfium2-4.30.1 python-iso639-2025.2.18 python-magic-0.4.27 python-oxmsg-0.0.2 rapidfuzz-3.13.0 regex-2024.11.6 requests-toolbelt-1.0.0 tenacity-9.1.2 tiktoken-0.9.0 tqdm-4.67.1 typing-inspect-0.9.0 typing-inspection-0.4.1 unstructured-0.18.3 unstructured-client-0.38.1 wrapt-1.17.2 zstandard-0.23.0
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pdfplumber
import os

def extract_text_from_pdf(file_path):
    all_text = ""
    with pdfplumber.open(file_path) as pdf:
        for page in pdf.pages:
            all_text += page.extract_text() + "\n"
    return all_text

medical_text = extract_text_from_pdf("medical_guideline.pdf")
print(medical_text[:1000])

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = text_splitter.split_text(medical_text)
print(chunks[:3])

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS

embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")

vectorstore = FAISS.from_texts(chunks, embedding=embedding_model)
retriever = vectorstore.as_retriever(search_type="similarity", k=4)

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA

llm = ChatOpenAI(model_name="gpt-4", temperature=0)

qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    return_source_documents=True
)

def ask_medical_question(query):
    result = qa_chain(query)
    return result["result"], result["source_documents"]

# %%
from ragas.metrics import (
    context_precision,
    context_recall,
    faithfulness,
    answer_relevancy
)
from ragas import evaluate
from datasets import Dataset

query = "What is the recommended dosage for metformin in type 2 diabetes?"
answer, source_docs = ask_medical_question(query)
contexts = [doc.page_content for doc in source_docs]

data = {
    "question": [query],
    "contexts": [contexts],
    "answer": [answer],
    "ground_truth": ["500 mg twice daily, based on ADA guidelines"]
}

ds = Dataset.from_dict(data)

ragas_results = evaluate(
    dataset=ds,
    metrics=[context_precision, context_recall, faithfulness, answer_relevancy]
)

ragas_results.to_pandas()
